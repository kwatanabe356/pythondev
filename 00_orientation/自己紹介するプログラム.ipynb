# %%
#命令1：名前を入力し、変数nameに格納する
name = input("名前を入力してください：")

#命令2：現在の年齢を入力し、変数ageに格納する
#input（）関数は文字列を返す為、int()関数で整数に変換する
age = input("現在の年齢を入力してください")
current_age = int(age)

#命令3：自己紹介文を表示し、来年の年齢を計算して表示する
next_age = current_age+1
print(f"私の名前は{name}です。来年で{next_age}歳になります。")
# Out:
# 私の名前は太郎　次郎です。来年で26歳になります。
