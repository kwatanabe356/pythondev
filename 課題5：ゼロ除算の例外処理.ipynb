# %%
try:
    a = int(input("割られる数を入力してください："))
    b = int(input("割る数を入力してください："))
    c = a / b

#エラー処理①　0の入力
except ZeroDivisionError:
    print("エラー：0で割算しないでください")
#エラー処理②　数値以外の入力
except ValueError:
    print("エラー：数値を入力してください")
else:
    print(f"{a} ÷ {b} = {c}")

finally:
    print("処理を終了します")
# Out:
# 10 ÷ 2 = 5.0
# 処理を終了します
